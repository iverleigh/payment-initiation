# %% [markdown]
# ## Generating Fake Data for our Natural Language Processing Model

# %% [markdown]
# Due to data confidentiality, we were unable to use a financial institution's real data. Consequently, we decided to  generate simulated data. The data is meant to resemble emails where a transfer of funds is requested between two accounts by an authorized user.

# %%
import numpy as np
import pandas as pd
import random
from faker import Faker
import string

# %%
emails = []
amounts = []
accountAs = []
accountBs = []
currency_codes = ['ALL', 'AFN', 'ARN', 'AWG', 'AUD' , 'AZN', 'BSD', 'BBD', 'BYN', 'BZD', 'BMD', 'BOB', 'BAM', 'BWP', 'BGN' ,'BRL', 'BND', 'KHR', 'CAD', 'KYD', 'CLP', 'CNY', 'COP', 'CRC', 'HRK', 'CUP', 'CZK', 'DKK', 'DOP', 'XCD', 'EGP', 'SVC', 'EUR', 'FKP', 'FJD', 'GHS', 'GIP','GTQ', 'GGP','GYD','HNL', 'HKD', 'HUF', 'ISK', 'INR', 'IDR', 'IRR', 'IMP', 'ILS', 'JMD', 'JPY', 'JEP', 'KZT', 'KPW', 'KRW', 'KGS', 'LAK','LBP', 'LRD', 'MKD', 'MYR', 'MUR','MXN', 'MNT', 'MZN', 'NAD', 'NPR', 'ANG','NZD', 'NIO', 'NGN', 'NOK', 'OMR', 'PKR', 'PAB', 'PYG', 'PEN','PHP', 'PLN', 'QAR', 'RON', 'RUB', 'SHP','SAR','RSD','SCR', 'SGD', 'SGD','SBD', 'SOS','ZAR','LKR','SEK','CHF','SRD','SYP','TWD','THB','TTD','TRY','TVD','UAH','GBP','USD','UYU','UZS','VEF','VND','YER','ZWD']
for i in range(2000):
    r = random.random()
    r2 = random.random()
    f = Faker()
    An = random.randint(5,12)
    Bn = random.randint(5,12)
    if r2 > 0.5:
        accountA = ''.join(random.choice(string.ascii_uppercase + string.digits + string.ascii_lowercase) for _ in range(An))
        accountB = ''.join(random.choice(string.ascii_lowercase + string.digits +  string.ascii_lowercase) for _ in range(Bn))
    if r2 < 0.5:
        accountA = ''.join(["%s" % random.randint(0, 9) for num in range(0, 9)])
        accountB = ''.join(["%s" % random.randint(0, 9) for num in range(0, 9)])
    amount = str(random.randint(2000, 10000000))
    if r < 0.05: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Goodmorning "+name+ ", I have a client in need of a money transfer. Could you transfer "+ amount +" "+ currency + " from account "+accountA +" to account "+accountB+". Please let me know as soon as this is complete. Thanks!"
    elif r >= 0.05 and r < 0.08: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi, I hope this email finds you well. We have an urgent request. Could "+amount+" "+ currency + " be transferred into account "+accountB+ " from "+accountA+"? Let me know. Have a great rest of your evening. Best regards," + name
    elif r >= 0.08 and r < 0.10:
        name = f.name()
        currency = random.choice(currency_codes)
        s = "To whom it may concern: Hi, I have a client who needs assistance with a transfer. We need to move "+amount + " "+ currency + " dollars as soon as possible. Would be great if you could move it from "+accountA + " to "+accountB+". How soon can this be done, and when will the funds be fully processed? Sincerely, " +name
    elif r >= 0.10 and r < 0.12: 
        name = f.name()
        name2 = f.name()
        currency = random.choice(currency_codes)
        s = "Dear "+ name+", at the request of our client, we need a transfer in the amount of "+amount+" "+ currency+". This needs to be completed today. Please move the funds from "+accountA+ "to "+accountB+". Please contact me back with any questions. Thanks, " + name2
    elif r >= 0.12 and r < 0.14: 
        currency = random.choice(currency_codes)
        s = "Hello. This email is provided at our customer's request to do the following transfer. Can you please transfer "+amount+ " "+ currency+ " and move this amount to "+accountB+" from "+ accountA+". Please email back when the proces is complete. Thank you!"
    elif r >= 0.14 and r < 0.16: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi this is "+name+". I need you to help me transfer "+amount + " "+ currency + " from "+accountA+" into "+accountB+". How soon can this be completed? Please let me know."
    elif r >= 0.16 and r < 0.18: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Dear "+name+", I am here to inform you of a bank transfer that my client is requesting. Could you move "+amount+" "+ currency+" from "+accountA+" into account "+accountB+". When will these funds be available? My client needs this to be completed as soon as possible."
    elif r >= 0.18 and r < 0.20: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hey "+ name+", I need to transfer "+amount+" "+ currency+" from account "+accountA+  " into "+accountB+". We need this done ASAP. Please double check and make sure that everything is correct before the transfer is placed. I have provided the details above. Please contact me after this is done. Thanks."
    elif r >= 0.20 and r < 0.22: 
        name = f.name()
        name2= f.name()
        currency = random.choice(currency_codes)
        s = "Hello "+name+", hope you are doing well. I am contacting you in need of assistance with a monetary transfer. We need a transfer of "+amount+ " "+ currency+", unless there is a maximum amount that can be performed per transfer. Please move this amount from "+accountA+" to account "+accountB+". Can this transaction be done? Let me know. Best, " +name2
    elif r >= 0.22 and r < 0.24: 
        currency = random.choice(currency_codes)
        s = "Good evening. I have a question regarding monetary transfers, can funds be transferred from corporate accounts to personal accounts? If so, please assist with a transfer of "+amount+ " "+ currency+ " into "+accountB+ " from corporate account "+ accountA+". Thanks."
    elif r >= 0.24 and r < 0.26: 
        currency = random.choice(currency_codes)
        s = "Hello, hope you are doing well. Could you please transfer "+ amount+ " "+ currency+" from "+ accountA + " to account "+accountB+", and let me know as soon as this is done."
    elif r >= 0.26 and r < 0.28: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "To whom it may concern: Hello I need assistance with a money transfer that will not go through. I'd like to move funds from "+accountA +" of the amount "+amount+" "+ currency+". This needs to be transferred to this account, "+accountB+". Best, " + name
    elif r >= 0.28 and r < 0.30: 
        currency = random.choice(currency_codes)
        name = f.name()
        s = "Hello and good evening. I, "+name+", am the account owner of the two bank accounts: "+accountA+" and " +accountB+". I need to move "+amount+" "+ currency+" dollars from "+accountA+" and deposit this into "+accountB+". Please make sure that all of the information is correct before submitting the transfer. Thank you so much."
    elif r >= 0.30 and r < 0.32: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi, can you please help me? There is a new deposit to the account "+accountA+" of the amount "+amount+ " "+ currency+". I need to transfer this exact amount moved into my business account, "+accountB+". How many business days will this transfer take? Thanks so much, " +name
    elif r >= 0.32 and r < 0.34: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Please move "+amount+" "+ currency + " from " + accountA+" to account "+ accountB +". Thank you very much. Sincerely, " +name
    elif r >= 0.34 and r < 0.36: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hello, this is my second attempt to contact you regarding a transfer request. I need this transfer to be completed ASAP. Please take "+amount+ " "+ currency +" from "+accountA+" and put this in account "+accountB + " . If this request cannot be fully processed in the next 3 business days, please let me know so that I can make other arrangements. Sincerely, " + name
    elif r >= 0.36 and r < 0.38:
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hello. We need a transfer of "+amount+" "+ currency+" from account "+accountA+ " to this account, "+accountB+". Thanks! " + name
    elif r >= 0.38 and r < 0.40: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Dear madam/sir, I, "+name+" am currently the account holder of the following bank accounts that are in need of a transfer. Please move "+amount+" "+ currency+" to "+accountB+" from "+accountA+". For some reason, this transfer will not go through when I do it. Thanks, " + name
    elif r >= 0.40 and r < 0.42:
        currency = random.choice(currency_codes)
        s = "Hey, I need help transferring "+amount+ " "+ currency+" from account "+accountA+ " to account "+accountB+". Thanks!"
    elif r >= 0.42 and r < 0.44: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Good afternoon. This needs IMMEDIATE attention!!! Please carefully move "+amount+ " "+ currency+" dollars from "+accountA+" into account "+accountB+". PLEASE make sure you are moving this amount from "+accountA+" to "+accountB+ ". Will you send me a receipt or confirmation of the transfer? Sincerely," +name
    elif r >= 0.44 and r < 0.46:
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi, can you please transfer "+amount+" "+ currency+" from account "+accountA+ " to the account "+accountB+". Thanks!" + name
    elif r >= 0.46 and r < 0.48: 
        currency = random.choice(currency_codes)
        s = "Account "+accountA +" needs "+amount+" "+ currency+" transferred to "+accountB+"."
    elif r >= 0.48 and r < 0.50: 
        name = f.name()
        currency = random.choice(currency_codes)
        name2= f.name()
        s = "Hello, this email is to confirm a monetary transfer request on behalf of my client, "+name2+". Please move "+amount+" "+ currency+" from my clients personal account,"+accountA+ ", to the corporate account, "+accountB+". Thank you very much. Sincerely," +name
    elif r >= 0.50 and r < 0.52: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi this is "+name+". I need you to do the following. Please help me transfer "+amount +" "+ currency+" from "+accountA+" into "+accountB+". Thanks."
    elif r >= 0.52 and r < 0.54: 
        name = f.name()
        name2 = f.name()
        currency = random.choice(currency_codes)
        s = "Hi "+name+", this email is to authorize a payment transfer request. We are in need of assistance, could you transfer "+amount+" "+ currency+" from "+accountA+ "to "+accountB+". This is of utmost importance because we have multiple clients waiting for these funds. Thank you so much. Best Regards, "+name2
    elif r >= 0.54 and r < 0.56: 
        currency = random.choice(currency_codes)
        s = "We need to remove "+amount+" "+ currency+" from "+accountA+" and deposit this into "+accountB+". Thanks. Let me know when it's done."
    elif r >= 0.56 and r < 0.58: 
        currency = random.choice(currency_codes)
        s = "Hi. I need help with a money transfer, I'd like this to be as soon as possible. Could you transfer "+amount+ " "+ currency+" from account "+accountA+" to account "+accountB+". Thanks and please contact me after it is finished."
    elif r >= 0.58 and r <= 0.60: 
        currency = random.choice(currency_codes)
        s = "We need to take the following action immediately! Move "+amount+" "+ currency+" into account "+accountB+ " from account "+ accountA+"!"
    elif r >= 0.60 and r < 0.62: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hello " + name+ ". Thanks for taking the time to read this email and assist with this transfer. I need you to move "+amount+" "+ currency+" from account "+accountA+" to "+accountB+". PLEASE MAKE SURE THE FUNDS ARE MOVING FROM "+accountA+" to "+accountB+"!!!! Please do not mix up the accounts. How soon can this be done? Please CALL me back, do NOT email."
    elif r >= 0.62 and r < 0.64: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hi, I have attempted (unsuccessfully) to conduct the following transfer. I'd like to submit a transfer request, please take account "+accountA+" and move "+amount+" "+ currency+" to account "+accountB+". I'm going to need this done as soon as you get the chance. I also will need a confirmation of this as soon as it is processed." + name
    elif r >= 0.64 and r < 0.66:
        currency = random.choice(currency_codes)
        s = "move " + amount + " "+ currency+ " to " + accountB + " from this account pls " + accountA
    elif r >= 0.66 and r < 0.68: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = name + " can u transfer " + amount + " "+ currency+ " to tjis account " + accountA + " from this account " + accountB
    elif r >= 0.68 and r < 0.70: 
        name = f.name()
        name2 = f.name()
        currency = random.choice(currency_codes)
        s = "Hey! "+name+" It's "+name2+". I would really appreciate if you could help me with something. I need to transfer "+amount+ " "+ currency+" from my personal bank account "+accountA+" to my restaurant's business account, "+accountB+". Will you let me know once everything is done? I'm really sorry, but this is really urgent. PLEASE send me notice when it is done."
    elif r >= 0.70 and r < 0.72: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "dear " + name +" can you make sure to mpve this amount " + amount +" "+ currency+ " from account " + accountA + " to " + accountB
    elif r >= 0.72 and r < 0.74: 
        name = f.name()
        name2 = f.name()
        currency = random.choice(currency_codes)
        s = "Hey!!! "+name+". Can you transfer "+amount+" "+ currency+" between two of my accounts? The funds need to be moved from this account "+accountA+" to my other account "+accountB+". Make sure you get those accounts correctly. Thanks! Best Regards, "+name2     
    elif r >= 0.74 and r < 0.76: 
        currency = random.choice(currency_codes)
        s = "Hello, this is an email regarding a transfer that I need assistance with. Please help me move "+amount+" "+ currency+" from "+ accountA+". The funds need to be transferred to the account "+accountB+". Can this be done? and when? Let me know if you need additional details. Thanks."
    elif r >= 0.76 and r <= 0.78: 
        currency = random.choice(currency_codes)
        s = "Good afternoon, we need assistance with a money transfer. We need this ASAP! Move "+amount+" "+ currency+" into account "+accountB+ " from account "+ accountA+". Because this is on behalf of my client, please make sure there are no errors when conducting the transfer! Thank you, please send confirmation after this is done."
    elif r >= 0.78 and r < 0.80: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = name + ", can u move this amt " + amount + " "+ currency+ " from " +accountA + " to this acct " + accountB + ", asap pls. thx"
    elif r >= 0.80 and r < 0.82: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Hello, I'm trying to transfer some funds between two of my accounts but it is not functioning. Please help me do the following. Move "+amount+" "+ currency+" from my savings account called "+accountA+" to my checking account "+accountB+". How will I know once this is completed? Will I be receiving confirmation via email? Best, " + name
    elif r >= 0.82 and r < 0.84:
        currency = random.choice(currency_codes)
        s = "hey id like to deposit " + amount + " "+ currency+" dollars into account " + accountA + " from this accoynt " + accountB
    elif r >= 0.84 and r <0.86: 
        currency = random.choice(currency_codes)
        name = f.name()
        s = "Dear "+name+", we need a transfer of "+amount+ " "+ currency+ " from the corporate account "+accountA+ "to my client's personal account "+accountB+". This needs to be done TODAY. Sorry to rush, but I have a client waiting. Thanks!"
    elif r >= 0.86 and r < 0.88: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "hey friend! can u help w a transfer? i need to take " + amount + " "+ currency+" from " +accountA + " nd put into acct "+ accountB +" thx " +name
    elif r >= 0.88 and r< 0.92: 
        currency = random.choice(currency_codes)
        s = "Hello. "+amount+" "+ currency+" needs to be moved from account "+accountA+ " to this account "+accountB+". Thanks!" + name
    elif r >= 0.92 and r < 0.96: 
        name = f.name()
        currency = random.choice(currency_codes)
        s = "Good evening, I am writing this email to authorize a transaction. Is the following amount feasible for a transfer? I need to move "+amount+" "+ currency+" from account "+accountA + " to "+accountB+". If there is any trouble, please don't hesitate to reach out. Thanks, " + name
    else: 
        name = f.name()
        name2 = f.name()
        currency = random.choice(currency_codes)
        s = "Hi, this is "+name+", and this is to confirm a transfer that my client, "+name2+", is requesting to be completed in the next couple of days. Could you move money from account "+accountA + " to account "+accountB+ " of the amount "+amount+" "+ currency+". Thank you! Please send me a receipt of the completed transfer for my client."
    
    emails.append(s)
    amounts.append(amount)
    accountAs.append(accountA)
    accountBs.append(accountB)
#df = pd.DataFrame()
#df['email'] = emails
#df['amount'] = amounts
#df['accountA'] = accountAs
#df['accountB'] = accountBs
#df.to_csv('data.csv',sep="|")

# %%
dta = list(zip(emails,amounts,accountAs,accountBs))
df = pd.DataFrame(dta)
df = df.rename(columns={0:"email",1:"amount",2:"accountA",3:"accountB"})
df.to_csv('data7.csv',sep="|",index=None)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
